# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.utils import shuffle
import random as rd
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
# %matplotlib inline

# %%
data = pd.read_excel(r'/content/GermanCreditData.xlsx',sheet_name='Sheet1')
data.head()
# Out:
#    Checking  Duration  History Purpose  Amount  Savings  Emploed  Installp  \
# 0         1         6        4       3    1169        5        5         4
# 1         2        48        2       3    5951        1        3         2
# 2         4        12        4       6    2096        1        4         2
# 3         1        42        2       2    7882        1        4         2
# 4         1        24        3       0    4870        1        3         3
#
#    marital  Coapp  ...  Age  Other  housing  Existcr  Job  Depends  Telephone  \
# 0        3      1  ...   67      3        2        2    3        1          2
# 1        2      1  ...   22      3        2        1    3        1          1
# 2        3      1  ...   49      3        2        1    2        2          1
# 3        3      3  ...   45      3        3        1    3        2          1
# 4        3      1  ...   53      3        3        2    3        2          1
#
#    Foreign  Bad  Good
# 0        1    0     1
# ...

# %%
data.isnull().sum()
# Out:
# Checking     0
# Duration     0
# History      0
# Purpose      0
# Amount       0
# Savings      0
# Emploed      0
# Installp     0
# marital      0
# Coapp        0
# Resident     0
# Property     0
# Age          0
# Other        0
# housing      0
# Existcr      0
# Job          0
# Depends      0
# Telephone    0
# Foreign      0
# Bad          0
# Good         0
# dtype: int64

# %%
data_check1 = data[data['Checking'] ==1] 
data_check2 = data[data['Checking'] ==2]
dfcheck12=pd.concat([data_check1,data_check2]) 
data_check3 = data[data['Checking'] ==3] 
data_check4 = data[data['Checking'] ==4]
dfcheck34=pd.concat([data_check3,data_check4])

# %%
dfcheck12.head()
# Out:
#     Checking  Duration  History Purpose  Amount  Savings  Emploed  Installp  \
# 0          1         6        4       3    1169        5        5         4
# 3          1        42        2       2    7882        1        4         2
# 4          1        24        3       0    4870        1        3         3
# 11         1        48        2       9    4308        1        2         3
# 13         1        24        4       0    1199        1        5         4
#
#     marital  Coapp  ...  Age  Other  housing  Existcr  Job  Depends  \
# 0         3      1  ...   67      3        2        2    3        1
# 3         3      3  ...   45      3        3        1    3        2
# 4         3      1  ...   53      3        3        2    3        2
# 11        2      1  ...   24      3        1        1    3        1
# 13        3      1  ...   60      3        2        2    2        1
#
#     Telephone  Foreign  Bad  Good
# 0           2        1    0     1
# ...

# %%
sns.set()
f, axes = plt.subplots(4, 2, figsize=(10,15))

sns.boxplot(y='Age', data=dfcheck12, ax=axes[0,0])
sns.boxplot(y='Amount', data=dfcheck12, ax=axes[0,1])
sns.boxplot(y='Depends', data=dfcheck12, ax=axes[1,0])
sns.boxplot(y='Duration', data=dfcheck12, ax=axes[1,1])
sns.boxplot(y='Existcr', data=dfcheck12, ax=axes[2,0])
sns.boxplot(y='Installp', data=dfcheck12, ax=axes[2,1])
sns.boxplot(y='Resident', data=dfcheck12, ax=axes[3,0])
# Out:
# <Axes: ylabel='Resident'>

# %%
dfcheck12.describe()
# Out:
#          Checking    Duration     History       Amount     Savings  \
# count  543.000000  543.000000  543.000000    543.00000  543.000000
# mean     1.495396   22.003683    2.353591   3498.38674    1.834254
# std      0.500440   12.710369    1.076511   3089.47241    1.438200
# min      1.000000    6.000000    0.000000    276.00000    1.000000
# 25%      1.000000   12.000000    2.000000   1356.50000    1.000000
# 50%      1.000000   18.000000    2.000000   2439.00000    1.000000
# 75%      2.000000   27.000000    3.000000   4289.00000    2.000000
# max      2.000000   72.000000    4.000000  18424.00000    5.000000
#
#           Emploed    Installp     marital       Coapp   Resident  ...  \
# count  543.000000  543.000000  543.000000  543.000000  543.00000  ...
# mean     3.252302    2.968692    2.666667    1.206262    2.87477  ...
# std      1.234823    1.130317    0.734830    0.568059    1.11637  ...
# min      1.000000    1.000000    1.000000    1.000000    1.00000  ...
# ...

# %%
Q1=dfcheck12['Age'].quantile(0.25)
Q3=dfcheck12['Age'].quantile(0.75)
IQR=Q3-Q1
IQR
whisker_width = 1.5
lower_whisker = Q1 -(whisker_width*IQR)
upper_whisker = Q3 +(whisker_width*IQR)
dfcheck12['Age']=np.where(dfcheck12['Age']>upper_whisker,upper_whisker,np.where(dfcheck12['Age']<lower_whisker,lower_whisker,dfcheck12['Age']))

# %%
dfcheck12['Age']
sns.boxplot(y='Age', data=dfcheck12)
# Out:
# <Axes: ylabel='Age'>

# %%
# Print outlier range for different variables and remove them from Exel directly (<= 12 months)

# Age
Age_IQR = dfcheck12.describe()['Age'][6]-dfcheck12.describe()['Age'][4]
Age_L = dfcheck12.describe()['Age'][4]-1.5*Age_IQR
Age_H = dfcheck12.describe()['Age'][6]+1.5*Age_IQR
print('Check=1,2 Age:', Age_L, '//', Age_H)

# Amount
Amount_IQR = dfcheck12.describe()['Amount'][6]-dfcheck12.describe()['Amount'][4]
Amount_L = dfcheck12.describe()['Amount'][4]-1.5*Amount_IQR
Amount_H = dfcheck12.describe()['Amount'][6]+1.5*Amount_IQR
print('Check=1,2 Amount:', Amount_L, '//', Amount_H)

# Existcr
Existcr_IQR = dfcheck12.describe()['Existcr'][6]-dfcheck12.describe()['Existcr'][4]
Existcr_L = dfcheck12.describe()['Existcr'][4]-1.5*Existcr_IQR
Existcr_H = dfcheck12.describe()['Existcr'][6]+1.5*Existcr_IQR
print('Check=1,2 Existcr:', Existcr_L, '//', Existcr_H)

# Duration
Duration_IQR = dfcheck12.describe()['Duration'][6]-dfcheck12.describe()['Duration'][4]
Duration_L = dfcheck12.describe()['Duration'][4]-1.5*Duration_IQR
Duration_H = dfcheck12.describe()['Duration'][6]+1.5*Duration_IQR
print('Check=1,2 Duration:', Duration_L, '//', Duration_H)
# Out:
# Check=1,2 Age: 5.0 // 61.0
# Check=1,2 Amount: -3042.25 // 8687.75
# Check=1,2 Existcr: -0.5 // 3.5
# Check=1,2 Duration: -10.5 // 49.5
